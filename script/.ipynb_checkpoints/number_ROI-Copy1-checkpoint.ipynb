# %%
import cv2
import numpy as np
from darkflow.net.build import TFNet
import matplotlib.pyplot as plt
import imutils

# %%
img = cv2.imread('/home/leij/Pictures/bus-test.png')
plt.imshow(img)

# %%
options = {
    'model': '/home/leij/obj-detection/darkflow-master/cfg/yolo.cfg',
    'load': '/home/leij/obj-detection/darkflow-master/bin/yolov2.weights',
    'threshold': 0.6,
    'gpu': 0.8
}
tfnet = TFNet(options)
# img = cv2.imread('/home/leij/obj-detection/darkflow-master/bus/bus-photos/IMG_20180421_155655.jpg', cv2.IMREAD_COLOR)

# img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
# result = tfnet.return_predict(img)
# Out:
# Parsing /home/leij/obj-detection/darkflow-master/cfg/yolo.cfg
# Loading /home/leij/obj-detection/darkflow-master/bin/yolov2.weights ...
# Successfully identified 203934260 bytes
# Finished in 0.021217823028564453s
# Model has a coco model name, loading coco labels.
# /home/leij/.virtualenvs/obj-detection-py3/lib/python3.5/site-packages/darkflow/dark/darknet.py:54: UserWarning: ./cfg/yolov2.cfg not found, use /home/leij/obj-detection/darkflow-master/cfg/yolo.cfg instead
#   cfg_path, FLAGS.model))
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-10-a2c494fa4549> in <module>()
#       5     'gpu': 0.8
#       6 }
# ----> 7 tfnet = TFNet(options)
#       8 # img = cv2.imread('/home/leij/obj-detection/darkflow-master/bus/bus-photos/IMG_20180421_155655.jpg', cv2.IMREAD_COLOR)
#       9
#
# ~/.virtualenvs/obj-detection-py3/lib/python3.5/site-packages/darkflow/net/build.py in __init__(self, FLAGS, darknet)
#      62                 args = [darknet.meta, FLAGS]
#      63                 self.num_layer = len(darknet.layers)
# ---> 64                 self.framework = create_framework(*args)
#      65
#      66                 self.meta = darknet.meta
#
# ~/.virtualenvs/obj-detection-py3/lib/python3.5/site-packages/darkflow/net/framework.py in create_framework(meta, FLAGS)
#      57     net_type = meta['type']
#      58     this = types.get(net_type, framework)
# ---> 59     return this(meta, FLAGS)
#
# ~/.virtualenvs/obj-detection-py3/lib/python3.5/site-packages/darkflow/net/framework.py in __init__(self, meta, FLAGS)
#      13         meta['name'] = model
#      14
# ---> 15         self.constructor(meta, FLAGS)
#      16
#      17     def is_inp(self, file_name):
#
# ~/.virtualenvs/obj-detection-py3/lib/python3.5/site-packages/darkflow/net/yolo/__init__.py in constructor(self, meta, FLAGS)
#      18                 return (b * 127, r * 127, g * 127)
#      19         if 'labels' not in meta:
# ---> 20                 misc.labels(meta, FLAGS) #We're not loading from a .pb so we do need to load the labels
#      21 	assert len(meta['labels']) == meta['classes'], (
#      22                 'labels.txt and {} indicate' + ' '
#
# ~/.virtualenvs/obj-detection-py3/lib/python3.5/site-packages/darkflow/net/yolo/misc.py in labels(meta, FLAGS)
#      34             print("Model has name yolo9000, loading yolo9000 labels.")
#      35             file = os.path.join(FLAGS.config, nine_names)
# ---> 36         with open(file, 'r') as f:
#      37             meta['labels'] = list()
#      38             labs = [l.strip() for l in f.readlines()]
#
# FileNotFoundError: [Errno 2] No such file or directory: './cfg/coco.names'

# %%
pwd
# Out:
# '/home/leij/obj-detection/darkflow-master/script'
