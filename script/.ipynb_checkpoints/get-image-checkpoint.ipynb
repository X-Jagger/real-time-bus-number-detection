# %%
import requests
from bs4 import BeautifulSoup
import re

r = requests.get("http://image.baidu.com/search/index?tn=baiduimage&ipn=r&ct=201326592&cl=2&lm=-1&st=-1&fm=result&fr=&sf=1&fmq=1524123017900_R&pv=&ic=0&nc=1&z=&se=1&showtab=0&fb=0&width=&height=&face=0&istype=2&ie=utf-8&word=bus")
# str = '"thumbURL":"http://img0.imgtn.bdimg.com/it/u=2000158775,786417739&fm=27&gp=0.jpg","replaceUrl".jpg'
pattern = re.compile(r'thumbURL.*?http.*?.jpg')
pattern2 = re.compile(r'http.*?.jpg')
items = pattern.findall(r.text)
imgs = [pattern2.findall(item)[0] for item in items]
imgs
# Out:
# ['http://img0.imgtn.bdimg.com/it/u=2000158775,786417739&fm=27&gp=0.jpg',
#  'http://img1.imgtn.bdimg.com/it/u=1130785820,510339479&fm=27&gp=0.jpg',
#  'http://img2.imgtn.bdimg.com/it/u=286448043,1227495353&fm=27&gp=0.jpg',
#  'http://img1.imgtn.bdimg.com/it/u=3843711436,3010145125&fm=200&gp=0.jpg',
#  'http://img0.imgtn.bdimg.com/it/u=3388254445,2738900271&fm=200&gp=0.jpg',
#  'http://img3.imgtn.bdimg.com/it/u=682583016,299811837&fm=200&gp=0.jpg',
#  'http://img1.imgtn.bdimg.com/it/u=2996650573,407678058&fm=27&gp=0.jpg',
#  'http://img5.imgtn.bdimg.com/it/u=355057505,1013867724&fm=27&gp=0.jpg',
#  'http://img3.imgtn.bdimg.com/it/u=3694507151,3038645786&fm=200&gp=0.jpg',
#  'http://img2.imgtn.bdimg.com/it/u=273649166,599581536&fm=27&gp=0.jpg',
#  'http://img2.imgtn.bdimg.com/it/u=2068211552,643028562&fm=200&gp=0.jpg',
#  'http://img0.imgtn.bdimg.com/it/u=2316471567,4176259699&fm=27&gp=0.jpg',
#  'http://img0.imgtn.bdimg.com/it/u=1489718214,1820829942&fm=27&gp=0.jpg',
# ...

# %%
headers = {'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10_11_5) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/50.0.2661.102 Safari/537.36'}
ir = requests.get('http://img0.imgtn.bdimg.com/it/u=2000158775,786417739&fm=27&gp=0.jpg',headers=headers)
ir.status_code
# Out:
# 200

# %% [raw]
# bs = BeautifulSoup(r.text,'lxml')
# # image = bs.find("a", {"id": "logo"}).find("img")["src"]
#
# # ir = requests.get(image)
# # if ir.status_code == 200:
# #     open('logo.jpg', 'wb').write(ir.content)
#
# # r.text
# bs

# %%
# image = bs.find("a", {"id": "logo"}).find("img")["src"]
# image
import re
scripts = bs.find_all('script')
scripts
# for img in imgs:
#     if img['src']:
#         print(img['src'])
# Out:
# [<script>
#      (function (context) {
#          var data = {};
#          var url = '//imgstat.baidu.com/17.gif';
#          var start = +new Date;
#          var createQuery = function (data) {
#              var ret = [];
#              for (var key in data) {
#                  ret.push(key + '=' + data[key]);
#              }
#              return ret.join('&');
#          };
#
#          var _mergeCommPara = function (data) {
#              data.etype = 'speed';
#              data.page = 'result';
#              data.logid = "10930043406991992454";
#              data.sid = '1ee06d2489d30a7aee42884b942df3d0f8b2d6a3';
#              data.wh = window.screen.width + 'x' + window.screen.height ;
#              data.sampid = '-1';
#              data.app = 'searchresult';
#              data.spat = 0 + '-' + '';
#              data.protocol = window.location.protocol.replace(':', '');
#              if ('0' - 0) {
#                  data.ishttps = '0';
#              }
#
# ...

# %%
open('/home/leij/obj-detection/darkflow-master/bus/txt.txt','w').write("ss")
# Out:
# 2

# %%
#download baidu images
